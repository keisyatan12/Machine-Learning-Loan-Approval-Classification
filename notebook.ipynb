# %% [markdown]
# # Mini Project Machine Learning
# Nama anggota: <br>
# 1. Keisya                               (221402006) <br>
# 2. Yohana Marito M.                     (221402065) <br>
# 3. Sintong Sutanto Johanes L. Tobing    (221402076) <br>

# %% [markdown]
# Dataset yang akan kami gunakan pada project kali ini berjudul <b>Loan Approval Classification Dataset</b>. Berikut ini adalah deskripsi mengenai kolom yang terdapat dalam dataset tersebut:
# <li>person_age:	Age of the person</li>
# <li>person_gender: Gender of the person</li>
# <li>person_education: Highest education level</li>
# <li>person_income: Annual income</li>
# <li>person_emp_exp: Years of employment experience</li>
# <li>person_home_ownership: Home ownership status (e.g., rent, own, mortgage)</li>
# <li>loan_amnt: Loan amount requested</li>
# <li>loan_intent: Purpose of the loan</li>
# <li>loan_int_rate: Loan interest rate</li>
# <li>loan_percent_income: Loan amount as a percentage of annual income</li>
# <li>cb_person_cred_hist_length:	Length of credit history in years</li>
# <li>credit_score: Credit score of the person</li>
# <li>previous_loan_defaults_on_file:	Indicator of previous loan defaults</li>
# <li>loan_status (target variable):	Loan approval status: 1 = approved; 0 = rejected</li>

# %%
# Melakukan import pada library yang akan dipakai.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Melakukan read pada file csv menggunakan Pandas.
df = pd.read_csv('loan_data.csv')

# %%
# Menampilkan dataframe df.
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
# Mengatur tampilan angka desimal pada dataframe dengan format '{:.2f}' sehingga angka desimal akan ditampilkan dengan dua angka di belakang koma.
pd.set_option('display.float_format', '{:.2f}'.format)

# Mengatur tampilan grafik dengan latar belakang putih dan garis kisi (grid).
sns.set(style="whitegrid")

# %%
# Menampilkan informasi dan statistik dari data.
print("Basic Information of the Dataset:")
print(df.info())
print("\nSummary Statistics of Numeric Features:")
print(df.describe())
# Out:
# Basic Information of the Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
# ...

# %%
# Melakukan pengecekan missing values.
print("\nMissing Values in Each Column:")
print(df.isnull().sum())
# Out:
# Missing Values in Each Column:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_income                     0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# loan_percent_income               0
# cb_person_cred_hist_length        0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %%
# Membuat visualisasi distribusi dari kolom loan_status pada dataset menggunakan barplot. NB: "Loan Status" : 1 = approved; 0 = rejected
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='loan_status', hue='loan_status', palette='viridis', legend=False)
plt.title('Distribution of Loan Status')
plt.show()

# %%
# Membuat histogram distribusi dari beberapa kolom numerik dalam dataset df.
numeric_features = ['person_age', 'person_income', 'person_emp_exp', 'loan_amnt', 
                    'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length', 'credit_score']

plt.figure(figsize=(15, 12))
for i, feature in enumerate(numeric_features, 1):
    plt.subplot(3, 3, i)
    sns.histplot(df[feature], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribution of {feature}')
plt.tight_layout()
plt.show()

# %%
# Mengidentifikasi outliers pada kolom person_age dalam df dengan cara memfilter df untuk menampilkan baris-baris di mana nilai person_age >80.
print("\nAge Outliers:")
df[df['person_age'] > 80]
# Out:
# Age Outliers:
#        person_age person_gender person_education  person_income  \
# 81         144.00          male         Bachelor      300616.00
# 183        144.00          male        Associate      241424.00
# 575        123.00        female      High School       97140.00
# 747        123.00          male         Bachelor       94723.00
# 32297      144.00        female        Associate     7200766.00
# 32416       94.00          male      High School       29738.00
# 32506       84.00          male      High School      114705.00
# 37930      116.00          male         Bachelor     5545545.00
# 38113      109.00          male      High School     5556399.00
#
#        person_emp_exp person_home_ownership  loan_amnt loan_intent  \
# 81                125                  RENT    4800.00     VENTURE
# 183               121              MORTGAGE    6000.00   EDUCATION
# 575               101                  RENT   20400.00   EDUCATION
# ...

# %%
# Mengidentifikasi outliers pada kolom person_income dalam df dengan cara memfilter df untuk menampilkan baris-baris di mana nilai person_income >1000000.
print("\nIncome Outliers:")
df[df['person_income'] > 1000000]
# Out:
# Income Outliers:
#        person_age person_gender person_education  person_income  \
# 17833       32.00        female      High School     1440746.00
# 17834       34.00          male         Bachelor     1138723.00
# 29119       36.00          male        Doctorate     1440982.00
# 29120       40.00        female         Bachelor     1440915.00
# 29121       50.00          male      High School     1081082.00
# 29122       36.00        female      High School     1081254.00
# 29345       42.00          male      High School     1067921.00
# 30049       42.00          male      High School     2448661.00
# 31921       37.00          male        Associate     1081139.00
# 31922       47.00          male      High School     1635757.00
# 31924       44.00          male      High School     1728974.00
# 32297      144.00        female        Associate     7200766.00
# 32298       58.00          male           Master     1080918.00
# ...

# %%
# Membuat visualisasi distribusi beberapa kolom kategorikal dalam dataset df.
categorical_features = ['person_gender', 'person_education', 'person_home_ownership', 'loan_intent', 'previous_loan_defaults_on_file']

plt.figure(figsize=(15, 12))
for i, feature in enumerate(categorical_features, 1):
    plt.subplot(3, 2, i)
    sns.countplot(data=df, x=feature, hue=feature, palette='viridis',legend=False)
    plt.title(f'Distribution of {feature}')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Membuat correlation matrix dari kolom numerik.
numeric_fitur = ['person_age', 'person_income', 'person_emp_exp', 'loan_amnt', 
                    'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length', 'credit_score', 'loan_status']
plt.figure(figsize=(10, 8))
correlation_matrix = df[numeric_fitur].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix of Numeric Features")
plt.show()

# %%
# Membuat scatter plot yang menunjukkan hubungan antara person_income dan loan_amnt dalam df, dengan kategori loan_status yang ditandai dengan warna yang berbeda.
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='person_income', y='loan_amnt', hue='loan_status', palette='viridis', alpha=0.6)
plt.title("Relationship between Income and Loan Amount")
plt.show()

# %%
# Analyzing Relationship between Credit Score and Loan Approval
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='loan_status', y='credit_score', palette='viridis')
plt.title("Credit Score Distribution by Loan Status")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6596\2620393474.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='loan_status', y='credit_score', palette='viridis')

# %%
# Analyzing Employment Experience vs Loan Approval
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='loan_status', y='person_emp_exp', palette='viridis')
plt.title("Employment Experience Distribution by Loan Status")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6596\100684773.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='loan_status', y='person_emp_exp', palette='viridis')

# %%
# Boxplot to visualize outliers
plt.figure(figsize=(12, 8))

# Boxplot to visualize outliers
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
sns.boxplot(x=df['loan_int_rate'])
plt.title('Boxplot of Loan Interest rate')

plt.subplot(2, 2, 2)
sns.boxplot(x=df['loan_amnt'])
plt.title('Boxplot of Loan Amount')

plt.subplot(2, 2, 3)
sns.boxplot(x=df['person_age'])
plt.title('Boxplot of Person Age')

plt.subplot(2, 2, 4)
sns.boxplot(x=df['loan_percent_income'])
plt.title('Boxplot of Loan Incomes Percent')

plt.tight_layout()
plt.show()

# %%
# Menghapus outliers pada dataset
cols = ['person_age', 'loan_int_rate', 'loan_amnt','loan_percent_income', 'cb_person_cred_hist_length'] # one or more

Q1 = df[cols].quantile(0.25)
Q3 = df[cols].quantile(0.75)
IQR = Q3 - Q1

df = df[~((df[cols] < (Q1 - 1.5 * IQR)) |(df[cols] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
# Mengecek kembali boxplot untuk melihat perubahan setelah outliers dihapus
plt.figure(figsize=(12, 8))

# Boxplot to visualize outliers
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
sns.boxplot(x=df['loan_int_rate'])
plt.title('Boxplot of Loan Interest rate')

plt.subplot(2, 2, 2)
sns.boxplot(x=df['loan_amnt'])
plt.title('Boxplot of Loan Amount')

plt.subplot(2, 2, 3)
sns.boxplot(x=df['person_age'])
plt.title('Boxplot of Person Age')

plt.subplot(2, 2, 4)
sns.boxplot(x=df['loan_percent_income'])
plt.title('Boxplot of Loan Incomes Percent')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
import joblib

# Define columns for encoding
categorical_columns = [
    'person_education', 
    'person_home_ownership', 
    'loan_intent', 
    'person_gender', 
    'previous_loan_defaults_on_file'
]

# Initialize OneHotEncoder
encoder = OneHotEncoder(sparse_output=False, dtype=int, handle_unknown='ignore')

# Fit and transform the encoder on the categorical columns
encoded_data = encoder.fit_transform(df[categorical_columns])

# Create a DataFrame with the encoded column names and enforce integer dtype
encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(categorical_columns), dtype=int, index=df.index)

# Combine with the original DataFrame (dropping the original categorical columns)
df_encoded = pd.concat([df.drop(columns=categorical_columns), encoded_df], axis=1)

# Save the encoder to use it in an API
joblib.dump(encoder, 'onehot_encoder.pkl')

# Display the encoded DataFrame
print(df_encoded.head())
# Out:
#     person_age  person_income  person_emp_exp  loan_amnt  loan_int_rate  \
# 1        21.00       12282.00               0    1000.00          11.14
# 5        21.00       12951.00               0    2500.00           7.14
# 9        21.00       12739.00               0    1600.00          14.74
# 11       21.00       13113.00               0    4500.00           8.63
# 19       24.00       14283.00               1    1750.00          10.99
#
#     loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 1                  0.08                        2.00           504
# 5                  0.19                        2.00           532
# 9                  0.13                        3.00           640
# 11                 0.34                        2.00           651
# 19                 0.12                        2.00           679
#
#     loan_status  person_education_Associate  ...  \
# 1             0                           0  ...
# ...

# %%
# Melakukan pengecekan missing values.
print("\nMissing Values in Each Column:")
print(df_encoded.isnull().sum())
# Out:
# Missing Values in Each Column:
# person_age                            0
# person_income                         0
# person_emp_exp                        0
# loan_amnt                             0
# loan_int_rate                         0
# loan_percent_income                   0
# cb_person_cred_hist_length            0
# credit_score                          0
# loan_status                           0
# person_education_Associate            0
# person_education_Bachelor             0
# person_education_Doctorate            0
# person_education_High School          0
# person_education_Master               0
# person_home_ownership_MORTGAGE        0
# person_home_ownership_OTHER           0
# person_home_ownership_OWN             0
# person_home_ownership_RENT            0
# loan_intent_DEBTCONSOLIDATION         0
# loan_intent_EDUCATION                 0
# loan_intent_HOMEIMPROVEMENT           0
# loan_intent_MEDICAL                   0
# loan_intent_PERSONAL                  0
# ...

# %%
# Memisahkan kolom (independent variables) dan target (dependent variable) dalam dataset
x = df_encoded.drop(columns=['loan_status'])
y = df_encoded['loan_status']

# %%
from sklearn.preprocessing import StandardScaler
import joblib
scaler = StandardScaler()

x_scaled = scaler.fit_transform(x)

x_scaled_df = pd.DataFrame(x_scaled, columns=x.columns)

joblib.dump(scaler, 'scaler.pkl')
x_scaled_df
# Out:
#        person_age  person_income  person_emp_exp  loan_amnt  loan_int_rate  \
# 0           -1.37          -1.28           -1.04      -1.53           0.08
# 1           -1.37          -1.27           -1.04      -1.23          -1.28
# 2           -1.37          -1.27           -1.04      -1.41           1.31
# 3           -1.37          -1.27           -1.04      -0.82          -0.77
# 4           -0.65          -1.24           -0.80      -1.38           0.03
# ...           ...            ...             ...        ...            ...
# 39508        0.07          -0.56            0.39       1.31           1.63
# 39509        2.48          -0.20            3.01       0.09           1.09
# 39510        1.52          -0.38            0.63      -1.17          -0.30
# 39511        0.55          -0.86           -0.09       0.70           0.80
# 39512       -0.65          -0.49           -0.80      -0.38           2.10
#
# ...

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
x_resampled, y_resampled = smote.fit_resample(x_scaled_df, y)
print(pd.Series(y_resampled).value_counts())
# Out:
# loan_status
# 0    31333
# 1    31333
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
print("Class Distribution After Resampling:")
print(pd.Series(y_resampled).value_counts())

plt.figure(figsize=(6, 6))
class_counts = pd.Series(y_resampled).value_counts()
class_counts.plot.pie(
    autopct='%1.1f%%', 
    labels=['Approved', 'Rejected'], 
    colors=['skyblue', 'salmon'], 
    startangle=90,
    wedgeprops={'edgecolor': 'black'}
)
plt.title('Class Distribution After SMOTE')
plt.ylabel('')
plt.show()
# Out:
# Class Distribution After Resampling:
# loan_status
# 0    31333
# 1    31333
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
import joblib
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, classification_report, confusion_matrix


x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.2, random_state=42)

# Define the cross-validation strategy
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

model_lr = LogisticRegression(random_state=42)
model_lr.fit(x_train, y_train)

joblib.dump(model_lr, 'model_logistic_regression.pkl')

loaded_model = joblib.load('model_logistic_regression.pkl')

y_pred_loaded = loaded_model.predict(x_test)
y_pred_proba_loaded = loaded_model.predict_proba(x_test)[:, 1]

precision_loaded_lr = precision_score(y_test, y_pred_loaded)
recall_loaded_lr = recall_score(y_test, y_pred_loaded)
f1_loaded_lr = f1_score(y_test, y_pred_loaded)
roc_loaded_lr = roc_auc_score(y_test, y_pred_proba_loaded)

# Evaluate the model using cross-validation
cv_precision_lr = cross_val_score(model_lr, x_resampled, y_resampled, cv=cv, scoring='precision')
cv_recall_lr = cross_val_score(model_lr, x_resampled, y_resampled, cv=cv, scoring='recall')
cv_f1_lr = cross_val_score(model_lr, x_resampled, y_resampled, cv=cv, scoring='f1')
cv_roc_auc_lr = cross_val_score(model_lr, x_resampled, y_resampled, cv=cv, scoring='roc_auc')

# Print the cross-validation results
print("Cross-Validation Evaluation Metrics for Logistic Regression Classifier")
print(f"Precision: {np.mean(cv_precision_lr):.4f} ± {np.std(cv_precision_lr):.4f}")
print(f"Recall: {np.mean(cv_recall_lr):.4f} ± {np.std(cv_recall_lr):.4f}")
print(f"F1 Score: {np.mean(cv_f1_lr):.4f} ± {np.std(cv_f1_lr):.4f}")
print(f"ROC AUC Score: {np.mean(cv_roc_auc_lr):.4f} ± {np.std(cv_roc_auc_lr):.4f}")

print(classification_report(y_test, y_pred_loaded))

print(confusion_matrix(y_test, y_pred_loaded))
# Out:
# Cross-Validation Evaluation Metrics for Logistic Regression Classifier
# Precision: 0.8595 ± 0.0027
# Recall: 0.9275 ± 0.0051
# F1 Score: 0.8922 ± 0.0023
# ROC AUC Score: 0.9567 ± 0.0016
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88      6182
#            1       0.86      0.93      0.89      6352
#
#     accuracy                           0.88     12534
#    macro avg       0.89      0.88      0.88     12534
# weighted avg       0.89      0.88      0.88     12534
#
# [[5197  985]
#  [ 464 5888]]

# %%
from xgboost import XGBClassifier

# Initialize the XGBoost model
model_xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)

# Fit the model to the training data
model_xgb.fit(x_train, y_train)

# Save the model to a file
joblib.dump(model_xgb, 'model_xgboost.pkl')

# Load the model from the file
loaded_model = joblib.load('model_xgboost.pkl')

# Make predictions with the loaded model
y_pred_loaded = loaded_model.predict(x_test)
y_pred_proba_loaded = loaded_model.predict_proba(x_test)[:, 1]

# Calculate evaluation metrics
precision_loaded_xg = precision_score(y_test, y_pred_loaded)
recall_loaded_xg = recall_score(y_test, y_pred_loaded)
f1_loaded_xg = f1_score(y_test, y_pred_loaded)
roc_loaded_xg = roc_auc_score(y_test, y_pred_proba_loaded)

# Evaluate the model using cross-validation
cv_precision_xg = cross_val_score(model_xgb, x_resampled, y_resampled, cv=cv, scoring='precision')
cv_recall_xg = cross_val_score(model_xgb, x_resampled, y_resampled, cv=cv, scoring='recall')
cv_f1_xg = cross_val_score(model_xgb, x_resampled, y_resampled, cv=cv, scoring='f1')
cv_roc_auc_xg = cross_val_score(model_xgb, x_resampled, y_resampled, cv=cv, scoring='roc_auc')

# Print the cross-validation results
print("Cross-Validation Evaluation Metrics for XGBoost Classifier")
print(f"Precision: {np.mean(cv_precision_xg):.4f} ± {np.std(cv_precision_xg):.4f}")
print(f"Recall: {np.mean(cv_recall_xg):.4f} ± {np.std(cv_recall_xg):.4f}")
print(f"F1 Score: {np.mean(cv_f1_xg):.4f} ± {np.std(cv_f1_xg):.4f}")
print(f"ROC AUC Score: {np.mean(cv_roc_auc_xg):.4f} ± {np.std(cv_roc_auc_xg):.4f}")

# Print the classification report and confusion matrix
print(classification_report(y_test, y_pred_loaded))
print(confusion_matrix(y_test, y_pred_loaded))
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [17:25:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [17:25:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [17:25:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, classification_report, confusion_matrix
import joblib
import numpy as np

# Initialize the Decision Tree model
model_dt = DecisionTreeClassifier(random_state=42)

# Split data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.2, random_state=42)

# Fit the model to the training data
model_dt.fit(x_train, y_train)

# Save the model to a file
joblib.dump(model_dt, 'model_decision_tree.pkl')

# Load the model from the file
loaded_model = joblib.load('model_decision_tree.pkl')

# Make predictions with the loaded model
y_pred_loaded = loaded_model.predict(x_test)
y_pred_proba_loaded = loaded_model.predict_proba(x_test)[:, 1] if hasattr(loaded_model, "predict_proba") else None

# Calculate evaluation metrics
precision_loaded_dt = precision_score(y_test, y_pred_loaded)
recall_loaded_dt = recall_score(y_test, y_pred_loaded)
f1_loaded_dt = f1_score(y_test, y_pred_loaded)
roc_loaded_dt = roc_auc_score(y_test, y_pred_proba_loaded) if y_pred_proba_loaded is not None else None

# Define cross-validation strategy
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Evaluate the model using cross-validation
cv_precision_dt = cross_val_score(model_dt, x_resampled, y_resampled, cv=cv, scoring='precision')
cv_recall_dt = cross_val_score(model_dt, x_resampled, y_resampled, cv=cv, scoring='recall')
cv_f1_dt = cross_val_score(model_dt, x_resampled, y_resampled, cv=cv, scoring='f1')
cv_roc_auc_dt = cross_val_score(model_dt, x_resampled, y_resampled, cv=cv, scoring='roc_auc')

# Print the cross-validation results
print("Cross-Validation Evaluation Metrics for Decision Tree Classifier")
print(f"Precision: {np.mean(cv_precision_dt):.4f} ± {np.std(cv_precision_dt):.4f}")
print(f"Recall: {np.mean(cv_recall_dt):.4f} ± {np.std(cv_recall_dt):.4f}")
print(f"F1 Score: {np.mean(cv_f1_dt):.4f} ± {np.std(cv_f1_dt):.4f}")
print(f"ROC AUC Score: {np.mean(cv_roc_auc_dt):.4f} ± {np.std(cv_roc_auc_dt):.4f}")

# Print the classification report and confusion matrix
print("Classification Report for Decision Tree Classifier")
print(classification_report(y_test, y_pred_loaded))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_loaded))
# Out:
# Cross-Validation Evaluation Metrics for Decision Tree Classifier
# Precision: 0.9029 ± 0.0023
# Recall: 0.9101 ± 0.0018
# F1 Score: 0.9065 ± 0.0015
# ROC AUC Score: 0.9061 ± 0.0015
# Classification Report for Decision Tree Classifier
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90      6182
#            1       0.90      0.91      0.90      6352
#
#     accuracy                           0.90     12534
#    macro avg       0.90      0.90      0.90     12534
# weighted avg       0.90      0.90      0.90     12534
#
# Confusion Matrix:
# [[5566  616]
#  [ 600 5752]]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, classification_report, confusion_matrix
from sklearn.model_selection import cross_val_score
import joblib
import numpy as np

# Initialize the Random Forest model
model_rf = RandomForestClassifier(random_state=42)

# Fit the model to the training data
model_rf.fit(x_train, y_train)

# Save the model to a file
joblib.dump(model_rf, 'model_random_forest.pkl')

# Load the model from the file
loaded_model = joblib.load('model_random_forest.pkl')

# Make predictions with the loaded model
y_pred_loaded = loaded_model.predict(x_test)
y_pred_proba_loaded = loaded_model.predict_proba(x_test)[:, 1]

# Calculate evaluation metrics
precision_loaded_rf = precision_score(y_test, y_pred_loaded)
recall_loaded_rf = recall_score(y_test, y_pred_loaded)
f1_loaded_rf = f1_score(y_test, y_pred_loaded)
roc_loaded_rf = roc_auc_score(y_test, y_pred_proba_loaded)

# Evaluate the model using cross-validation
cv_precision_rf = cross_val_score(model_rf, x_resampled, y_resampled, cv=cv, scoring='precision')
cv_recall_rf = cross_val_score(model_rf, x_resampled, y_resampled, cv=cv, scoring='recall')
cv_f1_rf = cross_val_score(model_rf, x_resampled, y_resampled, cv=cv, scoring='f1')
cv_roc_auc_rf = cross_val_score(model_rf, x_resampled, y_resampled, cv=cv, scoring='roc_auc')

# Print the cross-validation results
print("Cross-Validation Evaluation Metrics for Random Forest Classifier")
print(f"Precision: {np.mean(cv_precision_rf):.4f} ± {np.std(cv_precision_rf):.4f}")
print(f"Recall: {np.mean(cv_recall_rf):.4f} ± {np.std(cv_recall_rf):.4f}")
print(f"F1 Score: {np.mean(cv_f1_rf):.4f} ± {np.std(cv_f1_rf):.4f}")
print(f"ROC AUC Score: {np.mean(cv_roc_auc_rf):.4f} ± {np.std(cv_roc_auc_rf):.4f}")

# Print the classification report and confusion matrix
print(classification_report(y_test, y_pred_loaded))
print(confusion_matrix(y_test, y_pred_loaded))
# Out:
# Cross-Validation Evaluation Metrics for Random Forest Classifier
# Precision: 0.9284 ± 0.0034
# Recall: 0.9689 ± 0.0029
# F1 Score: 0.9482 ± 0.0027
# ROC AUC Score: 0.9907 ± 0.0005
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.94      6182
#            1       0.93      0.97      0.95      6352
#
#     accuracy                           0.95     12534
#    macro avg       0.95      0.95      0.95     12534
# weighted avg       0.95      0.95      0.95     12534
#
# [[5699  483]
#  [ 184 6168]]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, classification_report, confusion_matrix
import joblib
import numpy as np

# Define cross-validation strategy
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Define models to evaluate
models = {
    'Random Forest': RandomForestClassifier(random_state=42),
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'XGBoost': XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
    'Logistic Regression': LogisticRegression(random_state=42)
}

# Function to evaluate each model
def evaluate_model(model, x_resampled, y_resampled):
    precision = cross_val_score(model, x_resampled, y_resampled, cv=cv, scoring='precision')
    recall = cross_val_score(model, x_resampled, y_resampled, cv=cv, scoring='recall')
    f1 = cross_val_score(model, x_resampled, y_resampled, cv=cv, scoring='f1')
    roc_auc = cross_val_score(model, x_resampled, y_resampled, cv=cv, scoring='roc_auc')
    return {
        'Precision': (np.mean(precision), np.std(precision)),
        'Recall': (np.mean(recall), np.std(recall)),
        'F1 Score': (np.mean(f1), np.std(f1)),
        'ROC AUC': (np.mean(roc_auc), np.std(roc_auc))
    }

# Evaluate each model and store results
results = {}
for model_name, model in models.items():
    results[model_name] = evaluate_model(model, x_resampled, y_resampled)

# Print the comparison results
print("Cross-Validation Performance Comparison:")
for model_name, metrics in results.items():
    print(f"\n{model_name}:")
    for metric_name, (mean, std) in metrics.items():
        print(f"{metric_name}: {mean:.4f} ± {std:.4f}")
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [17:36:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [17:36:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [17:36:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# ...
